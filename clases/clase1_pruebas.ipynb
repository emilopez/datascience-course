# %% [markdown]
# # Clase 1 de python
#
# ## Primeros pasos en jupyter lab
#
# - Instalacion miniforge
# - Creacion del entorno virtual del curso
# - Usando **jupyter lab**

# %%
print("adios mundo")
print("esto es otro mensaje en la misma celda")
# Out:
# adios mundo
# esto es otro mensaje en la misma celda
