# %% [markdown]
# # Clase 1 - Introducción a la Ciencia de Datos con Python

# %% [markdown]
# ## Presentación del curso
# - Clase semanal: miércoles 18hs (presencial)
# - Objetivos
# - Requisitos para aprobar
# - Metodología de trabajo (notebooks, datasets reales)

# %% [markdown]
# ### Objetivos
# Este curso está orientado a introducir y aplicar herramientas modernas de ciencia de datos utilizando el ecosistema de Python.
# A lo largo del curso, los participantes aprenderán a procesar, analizar y visualizar datos de manera efectiva, integrando buenas prácticas de programación y flujo de trabajo reproducible.

# %% [markdown]
# ### Requisitos para aprobar
#
# - Exposición de avances en clases (3 o 4)
# - Trabajo final + exposición
# - Asistencia >= 80%

# %% [markdown]
# #### Evaluaciones/exposiciones
# - **Temas abarcados:** incluye los temas vistos?
# - **Complejidad:** es acorde al nivel?
# - **Resolución:** la solución desarrollada es la mejor?
# - **Claridad en la exposición**
#
# **Calificación final:**
# - 70 puntos suman las 3 unidades
# - 30 puntos el trabajo final
# - **Aprobado:** promedio > 70% de la nota (ninguna instancia < 60%) y asistencia del 80%

# %% [markdown]
# **Organización del contenido:** dividido en tres unidades
#
# - Unidad 1: Algoritmia computacional
# - Unidad 2: Procesamiento y visualización de datos
# - Unidad 3: Datos geoespaciales

# %% [markdown]
# - Presentación de los alumnos

# %% [markdown]
# ## ¿Por qué Python para Ciencia de Datos?
# - Comunidad científica muy activa
# - Fácil de extender
# - Ecosistema de librerías: pandas, polars, numpy, plotly, scikit-learn
# - Integración con otros lenguajes y plataformas

# %% [markdown]
# ## Entorno de trabajo
# - Miniconda Forge para instalar Python y librerías
# - Notebooks interactivos: Jupyter Lab y Marimo
# - Instrucciones: https://github.com/emilopez/datascience-course

# %% [markdown]
# # Python básico

# %% [markdown]
# ## Instalación
# - Seguir pasos de: https://github.com/emilopez/datascience-course/blob/main/install-howto.md

# %% [markdown]
# ## Estructuras de datos (contenedores) y control de flujo

# %%
# Variables básicas
edad = 25
nombre = 'Juan'
altura = 1.75
print(nombre, edad, altura)

# %%
# Listas
nombres = ['Ana', 'Luis', 'Pedro']
print(nombres[0])
nombres.append('Maria')
print(nombres)

# %%
# Diccionarios
persona = {'nombre': 'Juan', 'edad': 30, 'altura': 1.75}
print(persona['nombre'])

# %%
# Estructuras de control
for i in range(5):
    print('Número:', i)

x = 0
while x < 3:
    print('x vale', x)
    x += 1

if edad > 18:
    print('Es mayor de edad')

# %% [markdown]
# # Actividades con datos reales

# %% [markdown]
# ## Dataset 1: Localidades de Argentina
# Preguntas para resolver con bucles y condicionales:
# - ¿Cuántas localidades hay por provincia?
# - ¿Cuál es la provincia con más localidades?
# - ¿Cuál es el departamento con menos localidades?

# %%
# Ejemplo: abrir el archivo y procesar línea a línea
# (suponiendo CSV con columnas: localidad, departamento, provincia)
with open('localidades.csv', 'r', encoding='utf-8') as f:
    lineas = f.readlines()

# Celda vacía para que los estudiantes cuenten localidades por provincia

# %% [markdown]
# ## Dataset 2: Nombres de personas nacidas en Argentina (1922-2015)
# Preguntas para resolver:
# - ¿En qué año nacieron más personas?
# - ¿En qué año hubo menor 'variación' de nombres?
# - ¿En qué año hubo mayor 'variación' de nombres?
# - ¿Cuántas personas nacieron en 1980?
# - Graficar el número de nacimientos por año
# - ¿Cómo calcular la cantidad de nombres más frecuentes en cada década?

# %%
# Ejemplo: abrir el archivo y procesar
# (suponiendo CSV con columnas: anio, nombre, cantidad)
with open('nombres.csv', 'r', encoding='utf-8') as f:
    lineas = f.readlines()

# Celda vacía: ¿Cuántas personas nacieron en 1980?
